# %% [markdown]
# # Check the downloaded datasets

# %%
import os

# Check same images names are for each input/output
path_to = "../data/raw/manual-1k"
images_paths = sorted(os.listdir(f'{path_to}/images'))
print(len(images_paths))
print(images_paths[:5] + ['...'] + images_paths[-5:])
assert os.listdir(f'{path_to}images') ==\
    os.listdir(f'{path_to}masks/colors') ==\
    os.listdir(f'{path_to}masks/footprints') ==\
    os.listdir(f'{path_to}masks/walls')
# Out:
# 1007
# ['00000.png', '00001.png', '00002.png', '00003.png', '00004.png', '...', '01002.png', '01003.png', '01004.png', '01005.png', '01006.png']
